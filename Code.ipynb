# %%
#Importing required libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
#Reading the data 
data = pd.read_csv("athlete_events.csv")

# %%
#Printing the data
data
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
#Describing the dataset
data.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
#Printing the dimensions of dataset
print("Dataset Dimensions\nRows : {0}\nColumns : {1}".format(data.shape[0],data.shape[1]))
# Out:
# Dataset Dimensions
# Rows : 271116
# Columns : 15

# %%
#Cleaning the data frame
#Data Frame before dropping the columns
data
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
#Dropping the passed columns from the data frame
data.drop(["ID","Games","City","Event"],axis=1,inplace=True)
#Displaying the Data frame
data
# Out:
#                             Name Sex   Age  Height  Weight            Team  \
# 0                      A Dijiang   M  24.0   180.0    80.0           China
# 1                       A Lamusi   M  23.0   170.0    60.0           China
# 2            Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3           Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4       Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# ...                          ...  ..   ...     ...     ...             ...
# 271111                Andrzej ya   M  29.0   179.0    89.0        Poland-1
# 271112                  Piotr ya   M  27.0   176.0    59.0          Poland
# 271113                  Piotr ya   M  27.0   176.0    59.0          Poland
# 271114        Tomasz Ireneusz ya   M  30.0   185.0    96.0          Poland
# 271115        Tomasz Ireneusz ya   M  34.0   185.0    96.0          Poland
#
#         NOC  Year  Season          Sport Medal
# ...

# %%
#Finding all the null values
data.isnull().sum()
# Out:
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Year           0
# Season         0
# Sport          0
# Medal     231333
# dtype: int64

# %%
#Visualization of null values in dataset using heat map
sb.heatmap(data.isnull(), cbar=False)
plt.show()

# %%
# Imputing the null values with mean values of their respective columns

data["Medal"].fillna("No Medal", inplace = True)
data["Age"].fillna(data["Age"].mean(), inplace = True)
data["Height"].fillna(data["Height"].mean(), inplace = True)
data["Weight"].fillna(data["Weight"].mean(), inplace = True)


#for col in data.columns[data.isnull().any()]:
    #col = pd.Series(col)
    #data[col].fillna(data[col].mean(), inplace = True)

# %%
data.isnull().sum()
# Out:
# Name      0
# Sex       0
# Age       0
# Height    0
# Weight    0
# Team      0
# NOC       0
# Year      0
# Season    0
# Sport     0
# Medal     0
# dtype: int64

# %%
#Heatmap of null values in dataframe after imputing
sb.heatmap(data.isnull(),cbar=False)

# %%
#Printing the data after dropping the columns and imputing the null values
data
# Out:
#                             Name Sex   Age     Height     Weight  \
# 0                      A Dijiang   M  24.0  180.00000  80.000000
# 1                       A Lamusi   M  23.0  170.00000  60.000000
# 2            Gunnar Nielsen Aaby   M  24.0  175.33897  70.702393
# 3           Edgar Lindenau Aabye   M  34.0  175.33897  70.702393
# 4       Christine Jacoba Aaftink   F  21.0  185.00000  82.000000
# ...                          ...  ..   ...        ...        ...
# 271111                Andrzej ya   M  29.0  179.00000  89.000000
# 271112                  Piotr ya   M  27.0  176.00000  59.000000
# 271113                  Piotr ya   M  27.0  176.00000  59.000000
# 271114        Tomasz Ireneusz ya   M  30.0  185.00000  96.000000
# 271115        Tomasz Ireneusz ya   M  34.0  185.00000  96.000000
#
#                   Team  NOC  Year  Season          Sport     Medal
# 0                China  CHN  1992  Summer     Basketball  No Medal
# ...

# %%
# Sorting data for female participation in the Olympics.

womenInOlympics = data[data.Sex == 'F']

#Sorting data for male participation in the Olympics.

menInOlympics = data[data.Sex == 'M']

#Sorting data for female gold medallists above the age of 25 in the Olympics.

womenGoldAboveTwentyfive = data[(data.Sex == 'F') & (data.Medal == "Gold") & (data.Age > 25)]

# Sorting data for male gold medallists above the age of 30 in the Olympics.

menGoldAboveThirty = data[(data.Sex == 'M') & (data.Medal == "Gold") & (data.Age > 30)]

# Sorting data for medals won by India in the Olympics. 

medalsIndia = data[(data.Team == "India") & (data.Medal != "No Medal")]

# %%
# Plotting the graphs.

sb.set(style = "darkgrid")
plt.figure(figsize = (20, 10))
sb.countplot(x = 'Year', data = womenInOlympics)
plt.title("Participation of Women in Olympics")
# Out:
# Text(0.5, 1.0, 'Participation of Women in Olympics')

# %%
# Plotting the graphs.

sb.set(style = "darkgrid")
plt.figure(figsize = (20, 10))
sb.countplot(x = 'Year', data = menInOlympics)
plt.title("Participation of Men in Olympics")
# Out:
# Text(0.5, 1.0, 'Participation of Men in Olympics')

# %%
sb.set(style = "darkgrid")
plt.figure(figsize = (20, 10))
sb.countplot(x = "Year", data = womenGoldAboveTwentyfive)
plt.title("Women Gold Medallists Above the Age of TwentyFive")
# Out:
# Text(0.5, 1.0, 'Women Gold Medallists Above the Age of TwentyFive')

# %%
sb.set(style = "darkgrid")
plt.figure(figsize = (20, 10))
sb.countplot(x = "Year", data = menGoldAboveThirty)
plt.title("Men Gold Medallists Above the Age of Thirty")
# Out:
# Text(0.5, 1.0, 'Men Gold Medallists Above the Age of Thirty')

# %%
sb.set(style = "darkgrid")
plt.figure(figsize = (20, 10))
sb.countplot(x = "Year", data = medalsIndia)
plt.title("Medals Secured By India in Olympics")
# Out:
# Text(0.5, 1.0, 'Medals Secured By India in Olympics')

# %%
#Medal distributions
print(data[data.Medal.fillna('None')!='None'].Medal.value_counts())
# Out:
# No Medal    231333
# Gold         13372
# Bronze       13295
# Silver       13116
# Name: Medal, dtype: int64

# %%
#Country that has won the maximum gold medals in Summer Olympics.
goldMedals = data[(data.Medal == 'Gold') & (data.Season == 'Summer')].max()
print("Country that has won the highest number of gold medals in Summer Olympics:",goldMedals.Team)
#Country that has won the maximum gold medals in Winter Olympics.
goldMedals = data[(data.Medal == 'Gold') & (data.Season == 'Winter')].max()
print("Country that has won the highest number of gold medals in Winter Olympics:",goldMedals.Team)
#Country that has won the maximum silver medals in Summer Olympics.
silverMedals = data[(data.Medal == 'Silver') & (data.Season == 'Summer')].max()
print("Country that has won the highest number of silver medals in Summer Olympics:",silverMedals.Team)
#Country that has won the maximum silver medals in Winter Olympics.
silverMedals = data[(data.Medal == 'Silver') & (data.Season == 'Winter')].max()
print("Country that has won the highest number of silver medals in Winter Olympics:",silverMedals.Team)
#Country that has won the maximum bronze medals in Summer Olympics.
bronzeMedals = data[(data.Medal == 'Bronze') & (data.Season == 'Summer')].max()
print("Country that has won the highest number of bronze medals in Summer Olympics:",bronzeMedals.Team)
#Country that has won the maximum bronze medals in Winter Olympics.
bronzeMedals = data[(data.Medal == 'Bronze') & (data.Season == 'Winter')].max()
print("Country that has won the highest number of bronze medals in Winter Olympics:",bronzeMedals.Team)
# Out:
# Country that has won the highest number of gold medals in Summer Olympics: Zimbabwe
# Country that has won the highest number of gold medals in Winter Olympics: West Germany-2
# Country that has won the highest number of silver medals in Summer Olympics: Zut
# Country that has won the highest number of silver medals in Winter Olympics: Yugoslavia
# Country that has won the highest number of bronze medals in Summer Olympics: Zimbabwe
# Country that has won the highest number of bronze medals in Winter Olympics: Yugoslavia

# %%
#Plotting the graph for Variation of Height in both Men and Women using the boxplot
df = data[(data.Year>=1992)]
sb.boxplot(x="Year",y="Height",data=df,hue="Sex",width=0.9)
plt.title("Variation of Height in both Men and Women starting from the Year 1992")
plt.show()

# %%
#Plotting the graph for Variation of  Weight in both Men and Women using the boxplot
df = data[(data.Year>=1992)]
sb.boxplot(x="Year",y="Weight",data=df,hue="Sex",width=0.9)
plt.title("Variation of Weight in both men and women starting from the Year 1992")
plt.show()

# %%
# Standardizing the data 

# Printing mean values
print("Average height of participants in the Olympics is : ", data.Height.mean())
print("Average weight of participants in the Olympics is : ", data.Weight.mean())
print("Average age of participants in the Olympics is : ", data.Age.mean())

# Printing standard deviation
print("\nStandard Deviation in height of participants in the Olympics is : ", data.Height.std())
print("Standard Deviation in weight of participants in the Olympics is : ", data.Weight.std)
print("Standard Deviation in age of participants in the Olympics is : ", data.Age.std())

# Printing variance 
print("\nVariance in height of participants in the Olympics is : ", data.Height.mean())
print("Variance in weight of participants in the Olympics is : ", data.Weight.var())
print("Variance in age of participants in the Olympics is : ", data.Age.var())
# Out:
# Average height of participants in the Olympics is :  175.3389698736043
# Average weight of participants in the Olympics is :  70.70239290055207
# Average age of participants in the Olympics is :  25.55689835729893
#
# Standard Deviation in height of participants in the Olympics is :  9.278100378222124
# Standard Deviation in weight of participants in the Olympics is :  <bound method Series.std of 0         80.000000
# 1         60.000000
# 2         70.702393
# 3         70.702393
# 4         82.000000
#             ...
# 271111    89.000000
# 271112    59.000000
# 271113    59.000000
# 271114    96.000000
# 271115    96.000000
# Name: Weight, Length: 271116, dtype: float64>
# Standard Deviation in age of participants in the Olympics is :  6.280857346144234
#
# Variance in height of participants in the Olympics is :  175.3389698736043
# Variance in weight of participants in the Olympics is :  158.12282154913953
# ...

# %%
# Normalizing the data by printing the values between 0 and 1

print("Normalized data for height : ")
print((data.Height - data.Height.min())/(data.Height.max() - data.Height.min()))
print("\n")

print("Normalized data for weight : ")
print((data.Weight - data.Weight.min())/(data.Weight.max() - data.Weight.min()))
print("\n")

print("Normalized data for age : ")
print((data.Age - data.Age.min())/(data.Age.max() - data.Age.min()))
# Out:
# Normalized data for height :
# 0         0.535354
# 1         0.434343
# 2         0.488272
# 3         0.488272
# 4         0.585859
#             ...
# 271111    0.525253
# 271112    0.494949
# 271113    0.494949
# 271114    0.585859
# 271115    0.585859
# Name: Height, Length: 271116, dtype: float64
#
#
# Normalized data for weight :
# 0         0.291005
# 1         0.185185
# 2         0.241812
# 3         0.241812
# 4         0.301587
#             ...
# 271111    0.338624
# 271112    0.179894
# 271113    0.179894
# 271114    0.375661
# 271115    0.375661
# Name: Weight, Length: 271116, dtype: float64
#
#
# Normalized data for age :
# 0         0.160920
# 1         0.149425
# 2         0.160920
# 3         0.275862
# 4         0.126437
#             ...
# 271111    0.218391
# 271112    0.195402
# 271113    0.195402
# 271114    0.229885
# 271115    0.275862
# Name: Age, Length: 271116, dtype: float64

# %%
#collecting sample for correlation/ hypothesis about the dataset

#checking age of youngest male and female participants of 2000 olympics


lowest_age_female, lowest_age_male = data[data.Year==2000].groupby(by='Sex').Age.min()
print('In 2000 Olympics, age of youngest male was {0} and age of youngest female was {1}'.format(lowest_age_male, lowest_age_female))
# Out:
# In 2000 Olympics, age of youngest male was 14.0 and age of youngest female was 13.0

# %%
#percentage of male basketball players among all the male participants in 2000 olympics

total_male_players = data[(data.Year==2012) & (data.Sex=='M')].Name.nunique()
male_basketball_players = data[(data.Year==2000) & (data.Sex=='M') & (data.Sport=='Basketball')].Name.nunique()

print('Percentage of male basketball players among all male participants in 2000 was: {:.1f}%'.format(male_basketball_players*100/total_male_players))
# Out:
# Percentage of male basketball players among all male participants in 2000 was: 2.5%

# %%
#age category - fewest and the most number of participants of 2000 olymipcs

data_2000 = data[data.Year == 2000].drop_duplicates(subset='Name')
def age_category(age):
    '''Maps age to four categories'''

    if 15 <= age < 25:
        return '[15, 25)'
    elif 25 <= age < 35:
        return '[25, 35)'
    elif 35 <= age < 45:
        return '[35, 45)'
    return '[45, 55]'

# %%
data['age_category'] = data.Age.map(age_category)
(data[data.Year == 2000]
.drop_duplicates(subset='Name')  
.groupby('age_category')
.size())
# Out:
# age_category
# [15, 25)    4654
# [25, 35)    5334
# [35, 45)     589
# [45, 55]      62
# dtype: int64
